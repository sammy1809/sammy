# %%
import random
min_value = 1
max_value = 6
roll_again = "yes"
while roll_again =="yes":
    print("rolling the dice")
    print("the numbers are")
    print(random.randint(min_value,max_value))
    print(random.randint(min_value,max_value))
    roll_again = str(input("do we roll again"))
# Out:
# rolling the dice
# the numbers are
# 3
# 2
