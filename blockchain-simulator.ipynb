# %% [markdown]
# ## SAUMYA TIWARI
# ## EN19CS303047

# %% [markdown]
# ## BLOCKCHAIN SIMULATOR (CSCult)

# %%
import hashlib                 
import datetime as date        
import random  
class Block():
    def __init__(self, height, timestamp, prev_hash, txs):
        self.height = height
        self.timestamp = timestamp
        self.prev_hash = prev_hash
        self.hash = self.hash_block()
        self.transactions = txs
        self.tx_ctr = len(txs)
        self.merkle = self.merkle_root_hash(self.transactions)
        
    def hashing(self, string):
        string = string.encode()
        sha = hashlib.sha256(string).hexdigest()
        return sha
    def hash_block(self):
        string = str(self.height) + str(self.timestamp) + str(self.prev_hash)
        return self.hashing(string)
    def merkle_root_hash(self, txs):
        if (len(txs) == 1):
            return txs[0]
        txs_new = []
        for i in range(0, len(txs)-1, 2):
            txs_new.append(self.hashing(str(txs[i]) + str(txs[i+1])))
        if len(txs)%2 == 1:
            txs_new.append(self.hashing(str(txs[-1]) + str(txs[-1])))
        return self.merkle_root_hash(txs_new)
def create_genesis_block():
    return Block(0, date.datetime.now(), "0", [random.randint(1,1000) for _ in range(10)])
def next_block(last_block):
    this_height = last_block.height + 1
    this_timestamp = date.datetime.now()
    this_hash = last_block.hash
    this_txs = [random.randint(1,100) for _ in range(10)]
    return Block(this_height, this_timestamp, this_hash, this_txs)
if __name__=="__main__":
    Myblockchain = [create_genesis_block()]
    previous_block = Myblockchain[0]
    no_of_block = 10
for i in range(1, no_of_block +1):
    block_addition = next_block(previous_block)
    Myblockchain.append(block_addition)
    previous_block = block_addition
    print(
        (f"\nBlock #{i} has been added to the Myblockchain!\n"),
        ("\t\t{}\n".format("_"*10)),
        (f"\t\tHash: {block_addition.hash}"),
        (f"| Height of Block: {block_addition.height}"),
        (f"| Timestamp: {block_addition.timestamp}"),
        (f"| Previous Root Hash: {block_addition.prev_hash}"),
        (f"| Transactions: {block_addition.transactions}"),
        (f"| Transaction Counter: {block_addition.tx_ctr}"),
        (f"| Merkle Root Hash: {block_addition.merkle}"),
        ("\t\t{}".format("_"*10))
    )
# Out:
# Block #1 has been added to the Myblockchain!
#  		__________
#  		Hash: adb9db47008fb8aeee66b1a26ee61e93974e449e009ca2a43dee38334aca34dd | Height of Block: 1 | Timestamp: 2021-08-16 08:43:26.825628 | Previous Root Hash: 0a35a5408855b97b0de339f744510fa8b2d0d5830a7ad75fd56c4e3696293b50 | Transactions: [21, 22, 96, 58, 64, 10, 71, 51, 15, 76] | Transaction Counter: 10 | Merkle Root Hash: 80f159f70efc41a94a8783e76d51995f5a6a2484e7ffa25bb5c3eeb681a0a5a6 		__________
#
# Block #2 has been added to the Myblockchain!
#  		__________
#  		Hash: 49dca89a14f0976c04a90b61b787a6d55db3db079cdd440f40d0c8b1528363df | Height of Block: 2 | Timestamp: 2021-08-16 08:43:26.826156 | Previous Root Hash: adb9db47008fb8aeee66b1a26ee61e93974e449e009ca2a43dee38334aca34dd | Transactions: [52, 96, 44, 15, 60, 43, 57, 71, 83, 69] | Transaction Counter: 10 | Merkle Root Hash: a713d4b3fc6a9c4b44edc2784a32de7b381aba1701ca868cfc0581a6fbc12a37 		__________
#
# Block #3 has been added to the Myblockchain!
#  		__________
#  		Hash: e0c3117adf2c155ab16761c0dc197c848e16fb285891c1f929d25c4148a5ddad | Height of Block: 3 | Timestamp: 2021-08-16 08:43:26.826512 | Previous Root Hash: 49dca89a14f0976c04a90b61b787a6d55db3db079cdd440f40d0c8b1528363df | Transactions: [39, 54, 33, 82, 49, 85, 98, 97, 35, 56] | Transaction Counter: 10 | Merkle Root Hash: 7ae073156b1965a9315cf39d038a9c23bda418b73cafa25d01955960b33bad38 		__________
#
# Block #4 has been added to the Myblockchain!
#  		__________
#  		Hash: 1dfbae6e4f9fae8946907e12f92cfec2d2605eeb766b52dbca8074d936112f89 | Height of Block: 4 | Timestamp: 2021-08-16 08:43:26.826876 | Previous Root Hash: e0c3117adf2c155ab16761c0dc197c848e16fb285891c1f929d25c4148a5ddad | Transactions: [23, 84, 8, 82, 5, 17, 42, 7, 75, 7] | Transaction Counter: 10 | Merkle Root Hash: 8ec8df1dac37ac508b3f76e2132cd61157f0a9beced0818f04b16ded7613e00c 		__________
#
# Block #5 has been added to the Myblockchain!
#  		__________
#  		Hash: 682e7d0e2805816891c41ec833db719055ca1f698e2c03cb1da1d824d2518a6f | Height of Block: 5 | Timestamp: 2021-08-16 08:43:26.827197 | Previous Root Hash: 1dfbae6e4f9fae8946907e12f92cfec2d2605eeb766b52dbca8074d936112f89 | Transactions: [70, 45, 66, 59, 61, 42, 80, 84, 42, 34] | Transaction Counter: 10 | Merkle Root Hash: aefd0559e6b0717e29dda26d742a8d63a81db29537f68de5affedcb6fa84043e 		__________
#
# Block #6 has been added to the Myblockchain!
#  		__________
#  		Hash: 9b4661b0df53f0d5d94e098da4a12901c5b43725de6731cadba268a5f3a05000 | Height of Block: 6 | Timestamp: 2021-08-16 08:43:26.827484 | Previous Root Hash: 682e7d0e2805816891c41ec833db719055ca1f698e2c03cb1da1d824d2518a6f | Transactions: [85, 59, 4, 13, 41, 64, 91, 58, 54, 38] | Transaction Counter: 10 | Merkle Root Hash: 1570ce40d63d52b6b0fbe2e75ec8c325765caa305ec7e83923a883156b1c5214 		__________
#
# Block #7 has been added to the Myblockchain!
#  		__________
#  		Hash: 468876d75e8d50aa7bb482740d05d96a65d6bfeca54c3cf2e663b3a67e220360 | Height of Block: 7 | Timestamp: 2021-08-16 08:43:26.827812 | Previous Root Hash: 9b4661b0df53f0d5d94e098da4a12901c5b43725de6731cadba268a5f3a05000 | Transactions: [49, 5, 69, 77, 75, 30, 86, 65, 3, 18] | Transaction Counter: 10 | Merkle Root Hash: c0069d2823cd529dfef804a222f859cc8299c760c605c6937d38e4346435eefe 		__________
#
# Block #8 has been added to the Myblockchain!
#  		__________
#  		Hash: 59808d7ed94f0812df8fe1e3e9dbb5c54ca0c7bd3b96fa8c26b9acf619ca20d9 | Height of Block: 8 | Timestamp: 2021-08-16 08:43:26.828124 | Previous Root Hash: 468876d75e8d50aa7bb482740d05d96a65d6bfeca54c3cf2e663b3a67e220360 | Transactions: [17, 90, 3, 1, 61, 3, 68, 98, 38, 27] | Transaction Counter: 10 | Merkle Root Hash: 3498eb6a6079c49d64bc3c7abe6dea79afe3efd50ae8f0704e00056492d515ec 		__________
#
# Block #9 has been added to the Myblockchain!
#  		__________
#  		Hash: fad8cfa419a89c10bf2b8f6286d5b04a46be579dca3daacfa3bec39b7129e6de | Height of Block: 9 | Timestamp: 2021-08-16 08:43:26.828496 | Previous Root Hash: 59808d7ed94f0812df8fe1e3e9dbb5c54ca0c7bd3b96fa8c26b9acf619ca20d9 | Transactions: [81, 49, 60, 96, 75, 90, 9, 24, 59, 8] | Transaction Counter: 10 | Merkle Root Hash: 5037878633cf1d6715f4cb70f15d81361abedd879d2651564d68933055f05c5f 		__________
#
# Block #10 has been added to the Myblockchain!
#  		__________
#  		Hash: c132f492dfd354b4c4c86e9b171f0278f7850941bd492b0b67b630102e8f2da1 | Height of Block: 10 | Timestamp: 2021-08-16 08:43:26.828800 | Previous Root Hash: fad8cfa419a89c10bf2b8f6286d5b04a46be579dca3daacfa3bec39b7129e6de | Transactions: [52, 57, 95, 7, 1, 7, 100, 35, 59, 60] | Transaction Counter: 10 | Merkle Root Hash: 867336b7ba8efb7f03717bc765f0863b226e4d84a5cd88e1a5ae2ad1665286de 		__________
